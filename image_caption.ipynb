# %%
import warnings
warnings.filterwarnings(action = 'ignore')

# %%
from transformers import pipeline
from transformers.utils import logging
logging.set_verbosity(40)

# %%
from IPython.display import Image

# %%
# file 1
#https://drive.google.com/file/d/1AS93whZlhA2cNS3XVG8ibZZak90vqOWl/view?usp=sharing
# !gdown 1AS93whZlhA2cNS3XVG8ibZZak90vqOWl
file_name1 = "Batman-vs-Superman-Fight.jpg"
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1AS93whZlhA2cNS3XVG8ibZZak90vqOWl
# To: /content/Batman-vs-Superman-Fight.jpg
# 100% 382k/382k [00:00<00:00, 101MB/s]

# %%
# file 2
# https://drive.google.com/file/d/1YeUezeryr8HqBzu6BAQ25S74v5-oy6KR/view?usp=sharing
# !gdown 1YeUezeryr8HqBzu6BAQ25S74v5-oy6KR
file_name2 = "house_on_grass.jpg"
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1YeUezeryr8HqBzu6BAQ25S74v5-oy6KR
# To: /content/house_on_grass.jpg
# 100% 1.02M/1.02M [00:00<00:00, 102MB/s]

# %%
# file 3
# https://drive.google.com/file/d/1JbD_-kS0ZE70-q_63m-L6ipJOm7xm31F/view?usp=sharing
# !gdown 1JbD_-kS0ZE70-q_63m-L6ipJOm7xm31F
file_name3 = "skate_airtrick.jpg"
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1JbD_-kS0ZE70-q_63m-L6ipJOm7xm31F
# To: /content/skate_airtrick.jpg
# 100% 34.4k/34.4k [00:00<00:00, 72.0MB/s]

# %%
### Task: Image captioning
captioner = pipeline(task="image-to-text",
                     model="nlpconnect/vit-gpt2-image-captioning")
# Out:
# config.json:   0%|          | 0.00/4.61k [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/982M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/241 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/798k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/120 [00:00<?, ?B/s]
# preprocessor_config.json:   0%|          | 0.00/228 [00:00<?, ?B/s]

# %%
file_name = file_name1

# %%
captioner2 = pipeline("image-to-text", model="Salesforce/blip-image-captioning-base")
# Out:
# config.json:   0%|          | 0.00/4.56k [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/990M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/506 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/711k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/125 [00:00<?, ?B/s]
# preprocessor_config.json:   0%|          | 0.00/287 [00:00<?, ?B/s]

# %%
captioner3 = pipeline("image-to-text", model="microsoft/trocr-base-handwritten")
# Out:
# config.json:   0%|          | 0.00/4.17k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/1.33G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/1.12k [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/899k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/772 [00:00<?, ?B/s]
# preprocessor_config.json:   0%|          | 0.00/224 [00:00<?, ?B/s]

# %%
captioner(file_name)
# Out:
# [{'generated_text': 'a man in a costume holding a large object '}]

# %%
captioner2(file_name2)
# Out:
# [{'generated_text': 'an old house in the middle of nowhere'}]

# %%
captioner3(file_name3)
# Out:
# [{'generated_text': '2'}]

# %% [markdown]
# # Photo 1

# %%
print(captioner(file_name1))
display(Image(filename=file_name1))
# Out:
# [{'generated_text': 'a man in a costume holding a large object '}]

# %% [markdown]
# ## Photo 2

# %%
print(captioner2(file_name2))
display(Image(filename=file_name2))
# Out:
# [{'generated_text': 'an old house in the middle of nowhere'}]

# %% [markdown]
# # Photo 3

# %%
print(captioner3(file_name3))
display(Image(filename=file_name3))
# Out:
# [{'generated_text': '2'}]
